# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid_deaths = pd.read_csv("covid19_deaths_dataset.csv")

# %%
covid_deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_deaths.drop(["Lat", "Long"],axis=1,inplace=True)

# %%
covid_deaths.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_death_aggregated = covid_deaths.groupby("Country/Region").sum()

# %%
covid_death_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %%
covid_death_aggregated.loc["India"].diff().plot()

# %%
countries = list(covid_death_aggregated.index)
max_deaths = []
for i in countries:
                 max_deaths.append(covid_death_aggregated.loc[i].diff().max())

# %%
covid_death_aggregated["max_deaths_rate"] = max_deaths

# %%
covid_death_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
corona_deaths = pd.DataFrame(covid_death_aggregated["max_deaths_rate"])

# %%
corona_deaths.head()
# Out:
#                 max_deaths_rate
# Country/Region
# Afghanistan                 7.0
# Albania                     4.0
# Algeria                    30.0
# Andorra                     4.0
# Angola                      2.0

# %%
hr_data = pd.read_csv("worldwide_happiness_report.csv")

# %%
hr_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
hr_data.drop(useless_cols,axis=1,inplace=True)

# %%
hr_data.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
hr_data.set_index("Country or region", inplace=True)

# %%
hr_data.shape
# Out:
# (156, 5)

# %%
corona_deaths.head()
# Out:
#                 max_deaths_rate
# Country/Region
# Afghanistan                 7.0
# Albania                     4.0
# Algeria                    30.0
# Andorra                     4.0
# Angola                      2.0

# %%
data = corona_deaths.join(hr_data,how="inner")

# %%
data.corr()
# Out:
#                               max_deaths_rate  GDP per capita  Social support  \
# max_deaths_rate                      1.000000        0.259893        0.204148
# GDP per capita                       0.259893        1.000000        0.759468
# Social support                       0.204148        0.759468        1.000000
# Healthy life expectancy              0.309666        0.863062        0.765286
# Freedom to make life choices         0.080166        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_deaths_rate                              0.309666
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_deaths_rate                                   0.080166
# ...

# %%
x = data["GDP per capita"]
y = data["max_deaths_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# /Users/amogh/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
x = data["Healthy life expectancy"]
y = data["max_deaths_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# /Users/amogh/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
This shows that it is not because lesser developed countries have less testing kits which is why they have less confirmed cases
